# %%
# Import data
import pandas

rootSum = pandas.read_csv('/Users/emmahauser/OneDrive - The University of Montana/CZ chapter/RootVolSummary_101422.csv')

# %%
rootSum
# Out:
#             box  depth_m   area_km2   volume_km3  depth_km  depth_cm  \
# 0     potential     1.50  145092595  217638.8925   0.00150       150
# 1     shallower     0.43   70100000   30143.0000   0.00043        43
# 2        deeper     0.60   50600000   30360.0000   0.00060        60
# 3  contemporary     1.41  145092595  204580.5590   0.00141       141
#
#    area_10^7        length         width  length_10^3  width_10^3
# 0   14.50926  12045.438760  12045.438760    12.045439   12.045439
# 1    7.01000   8372.574276   8372.574276     8.372574    8.372574
# 2    5.06000   7113.367698   7113.367698     7.113368    7.113368
# 3   14.50926  12045.438760  12045.438760    12.045439   12.045439

# %%
##From: https://pythonprogramming.net/3d-bar-charts-python-matplotlib/


# %matplotlib notebook

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

xpos = [1,25,40,40]
ypos = [1, 15,27,50]
num_elements = len(xpos)
zpos = [0,0,0,0]
dx = [(12.045439*1.5),(8.372574*1.5),(7.113368*1.5),(12.045439*1.5)]
dy = [(12.045439*1.5),(8.372574*1.5),(7.113368*1.5),(12.045439*1.5)]
dz = [150,43,60,141]

names = ['Potential', 'Shallowing', 'Deepening', 'Contemporary']
ax1.bar3d(xpos, ypos, zpos, dx, dy, dz, color= ['honeydew', 'lightcoral','cornflowerblue','lightyellow'])
ax1.set_ylim(0,70)
ax1.set_zlim(0,150)
ax1.set_zlabel('Depth (cm)')
ax1.set_xlabel('')
#ax1.set_xlabel('X * Y = Area of rooting, km2 x 6.667^3')
sea = plt.Rectangle((0, 0), 1, 1, fc="honeydew")
red_proxy = plt.Rectangle((0, 0), 1, 1, fc="lightcoral")
blue_proxy = plt.Rectangle((0, 0), 1, 1, fc="cornflowerblue")
green_proxy = plt.Rectangle((0, 0), 1, 1, fc="lightyellow")
ax1.legend([sea, red_proxy, blue_proxy, green_proxy], ['Potential', 'Shallowing','Deepening','Contemporary'], loc = 1, bbox_to_anchor=(1.3, 1.1))
plt.figtext(0.5,0.04, "X * Y = Area of rooting, km2 x 4.445^3", ha="center", va="center", fontsize=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

xpos = [1,50,50 , 1]
ypos = [1, 25, 46, 75]
num_elements = len(xpos)
zpos = [0,0,0,0]
dx = [(12.045439*2),(8.372574*2),(7.113368*2),(12.045439*2)]
dy = [(12.045439*2),(8.372574*2),(7.113368*2),(12.045439*2)]
dz = [150,43,60,141]

names = ['Potential', 'Shallowing', 'Deepening', 'Contemporary']
ax1.bar3d(xpos, ypos, zpos, dx, dy, dz, color= ['limegreen', 'lightcoral','cornflowerblue','orange'])
ax1.set_ylim(0,95)
ax1.set_xlim(0,90)
#ax1.xticks(10)
#ax1.yticks(10)
ax1.xaxis.set_minor_locator(MultipleLocator(10))
ax1.set_zlim(0,150)
ax1.set_zlabel('Depth (cm)')
ax1.set_xlabel('')
#ax1.set_xlabel('X * Y = Area of rooting, km2 x 6.667^3')
sea = plt.Rectangle((0, 0), 1, 1, fc="limegreen")
red_proxy = plt.Rectangle((0, 0), 1, 1, fc="lightcoral")
blue_proxy = plt.Rectangle((0, 0), 1, 1, fc="cornflowerblue")
green_proxy = plt.Rectangle((0, 0), 1, 1, fc="orange")
ax1.legend([sea, red_proxy, blue_proxy, green_proxy], ['Potential', 'Shallowing','Deepening','Contemporary'], loc = 1, bbox_to_anchor=(1.3, 1.1))
plt.figtext(0.5,0.04, "X * Y = Area of rooting, km2 x 250", ha="center", va="center", fontsize=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Some useful links
# https://stackoverflow.com/questions/64656130/matplotlib-bar-chart-independently-adjust-alpha-values-for-specific-bars

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')


xpos = [1,50,50 , 1]
ypos = [1, 25, 46, 75]
num_elements = len(xpos)
zpos = [0,0,0,0]
dx = [(12.045439*2),(8.372574*2),(7.113368*2),(12.045439*2)]
dy = [(12.045439*2),(8.372574*2),(7.113368*2),(12.045439*2)]
dz = [150,43,60,141]

names = ['Potential', 'Shallowing', 'Deepening', 'Contemporary']
ax1.bar3d(xpos, ypos, zpos, dx, dy, dz, color= ['limegreen', 'lightcoral','cornflowerblue','yellow'])
ax1.set_ylim(0,95)
ax1.set_xlim(0,90)
#ax1.xticks(10)
#ax1.yticks(10)
ax1.xaxis.set_minor_locator(MultipleLocator(10))
ax1.set_zlim(0,150)
ax1.set_zlabel('Depth (cm)')
ax1.set_xlabel('')
#ax1.set_xlabel('X * Y = Area of rooting, km2 x 6.667^3')
sea = plt.Rectangle((0, 0), 1, 1, fc="limegreen")
red_proxy = plt.Rectangle((0, 0), 1, 1, fc="lightcoral")
blue_proxy = plt.Rectangle((0, 0), 1, 1, fc="cornflowerblue")
green_proxy = plt.Rectangle((0, 0), 1, 1, fc="yellow")
ax1.legend([sea, red_proxy, blue_proxy, green_proxy], ['Potential', 'Shallowing','Deepening','Contemporary'], loc = 1, bbox_to_anchor=(1.3, 1.1))
plt.figtext(0.5,0.04, "X * Y = Area of rooting, km2 x 250", ha="center", va="center", fontsize=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
